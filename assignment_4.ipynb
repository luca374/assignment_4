# %% [markdown]
# 1.Deﬁne functional requirements (job to be done) and information requirements. 2.Conduct data research to identify potential sources of data for addressing the persona’s information requirements in getting their job done. 3.Scrap data from sources (including current alternatives) for further analysis of shortcomings in existing information architecture and user interfaces. 4.Shortcomings include: missing information, fragmented information, inconsistent information, outdated information, and erroneous information. 5.Identify and perform data cleaning and data preparation (e.g. type conversion) if necessary to meet information requirements.  6.Describe strategy to obtain non-existing data to complete information requirements.

# %%
import requests
url = 'https://ecs.toranoana.jp/joshi/ec/app/catalog/list?coterieGenreCode1=GNRN00006324'
res =requests.get(url)
print(res.status_code)
# Out:
# 200

# %%
import requests
import csv
import pandas as pd
from bs4 import BeautifulSoup
import pandas as pd

fanbooks = []
prices = []
authors=[]
fanbook_status=[]
urls=[]
for i in range(1,11): # Page counter
    url = "https://ecs.toranoana.jp/joshi/ec/app/catalog/list?coterieGenreCode1=GNRN00006324"+str(i)
    headers ={'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/94.0.4606.81 Safari/537.36',
             'Cookie':'JALKSJFJASKDFJKALSJDFLJSF=1381681491196025ef2f67f54c29ace23bd2afd39ba0192.168.199.150_19515311395; Hm_lvt_75e110b2a3c6890a57de45bd2882ec7c=1633767512,1633767513,1633768086,1633770269; token=UhS7XYourE9UFKQ0iv632s5IzkUJoNZ7Avqtoz8gIof+9x1xBwHwsXdCPbJibOWe3WtThuio6LcUWMZLkfatBK8v77pO9DuPhTQvTpjVINt3pLKKLKeCvuHHn6J5v/D9PziPJCYp/kBjgqmzPVQlxurTr/6+vKC4S/MqCGpGYP4=; JSESSIONID=7EBDDA34FC569C523354863277CB65B2; Hm_lpvt_75e110b2a3c6890a57de45bd2882ec7c=1633877901'}
    res =requests.get("https://ecs.toranoana.jp/joshi/ec/app/catalog/list?coterieGenreCode1=GNRN00006324",headers = headers)
    print(res.status_code)
    quote_page = requests.get("https://ecs.toranoana.jp/joshi/ec/app/catalog/list?coterieGenreCode1=GNRN00006324") 
    print("\n***** Page " + str(i) +" in action *****")
    soup = BeautifulSoup(res.content,'html.parser')
    for item in soup.findAll("div", attrs={"class":"product-list-item-inn"}): 
         book=item.find("h3",attrs={"class":"product-list-title"}).get_text()
         price=item.find("h4",attrs={"class":"product-list-price"}).get_text()
         author=item.find("div",attrs={"class":"product-list-name"}).get_text()
         status=item.find("p",attrs={"class":"product-list-basic"}).get_text()
         link=item.find("h3",attrs={"class":"product-list-title"}).a.get('href')
         if book != None and price != None and author != None and status != None and link != None:
            fanbooks.append(book.strip())
            prices.append(price.strip())
            authors.append(author.strip())
            fanbook_status.append(status.strip())
            urls.append(link)
            
#print(fanbooks)
#print(prices)
#print(authors)
#print(fanbook_status)
#print(urls)
                
df=pd.DataFrame({"Fanbook name":fanbooks,"Price":prices,'Author':authors,'Fanbook status':fanbook_status,'Purchase Links':urls})           
df.to_csv('fanbook_information.csv', sep='\t', encoding='utf-8')
df
# Out:
# 200
#
# ***** Page 1 in action *****
# 200
#
# ***** Page 2 in action *****
# 200
#
# ***** Page 3 in action *****
# 200
#
# ***** Page 4 in action *****
# 200
#
# ***** Page 5 in action *****
# 200
#
# ***** Page 6 in action *****
# 200
#
# ***** Page 7 in action *****
# 200
#
# ***** Page 8 in action *****
# 200
#
# ***** Page 9 in action *****
# 200
#
# ***** Page 10 in action *****
#       Fanbook name       Price                    Author Fanbook status  \
# 0            世界の策略  1,257円（税込）                   ココノツノミチ      △：予約残りわずか
# 1           ずっともっと    787円（税込）                   煙霞ナトリウム        ○：予約受付中
# 2          天国へようこそ    944円（税込）  And But Cause I love you        ○：予約受付中
# 3          二人で刻む日々  1,729円（税込）               Helichrysum      △：予約残りわずか
# 4    NAZONO TAMAGO    315円（税込）                      もふり屋         ×：在庫なし
# ..             ...         ...                       ...            ...
# 495     パーフェクトサマチャ    707円（税込）                      トクセツ      △：予約残りわずか
# ...

# %%
import requests
import csv
import pandas as pd
from bs4 import BeautifulSoup
import pandas as pd

expos = []
times = []   
for i in range(1,2): # Page counter
    url = "https://www.allcpp.cn/allcpp/event/eventlist.do#p=1&type=4&g=0&s=&old=1&c=0&l=0"
    headers ={'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/94.0.4606.81 Safari/537.36',
             'Cookie':'JALKSJFJASKDFJKALSJDFLJSF=1381681491196025ef2f67f54c29ace23bd2afd39ba0192.168.199.150_19515311395; Hm_lvt_75e110b2a3c6890a57de45bd2882ec7c=1633767512,1633767513,1633768086,1633770269; token=UhS7XYourE9UFKQ0iv632s5IzkUJoNZ7Avqtoz8gIof+9x1xBwHwsXdCPbJibOWe3WtThuio6LcUWMZLkfatBK8v77pO9DuPhTQvTpjVINt3pLKKLKeCvuHHn6J5v/D9PziPJCYp/kBjgqmzPVQlxurTr/6+vKC4S/MqCGpGYP4=; JSESSIONID=7EBDDA34FC569C523354863277CB65B2; Hm_lpvt_75e110b2a3c6890a57de45bd2882ec7c=1633877901'}
    res =requests.get("https://www.allcpp.cn/allcpp/event/eventlist.do#p=1&type=4&g=0&s=&old=1&c=0&l=0",headers = headers)
    print(res.status_code)
    quote_page = requests.get("https://www.allcpp.cn/allcpp/event/eventlist.do#p=1&type=4&g=0&s=&old=1&c=0&l=0") 
    print("\n***** Page " + str(i) +" in action *****")
    soup = BeautifulSoup(res.content,'html.parser')
    for item in soup.findAll("div", attrs={"class":"eInfo"}):         
         name=item.find("div",attrs={"class":"eName"}).get_text()
         time=item.find("li",attrs={"class":"eDay"}).get_text()
         if name != None and time != None:
            expos.append(name.text.strip())
            times.append(time.text.strip())
            
print(expos)
                
df=pd.DataFrame({"Expo name":expos,"Time":times})           
df.to_csv('expo.csv', sep='\t', encoding='utf-8')
df
# Out:
# 200
#
# ***** Page 1 in action *****
# []
# Empty DataFrame
# Columns: [Expo name, Time]
# Index: []

# %%
import requests
url = 'https://beijing.douban.com/events/week-film'
headers ={'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/94.0.4606.81 Safari/537.36'}
res =requests.get(url,headers = headers)
print(res.status_code)
# Out:
# 200
